# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Installing Miniconda in Colab Environment

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Out:
# --2024-02-09 10:31:40--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 141613749 (135M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 135.05M   312MB/s    in 0.4s
#
# 2024-02-09 10:31:41 (312 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [141613749/141613749]

# %%
# !bash Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# ...
#
#
# ...
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
import os
os.environ['PATH'] = "/usr/local/bin:" + os.environ['PATH']

# %%
# !conda update -n base -c defaults conda -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2024.2.2           |  py311h06a4308_0         160 KB
#     conda-24.1.0               |  py311h06a4308_0         1.2 MB
#     openssl-3.0.13             |       h7f8727e_0         5.2 MB
#     ------------------------------------------------------------
#                                            Total:         6.6 MB
#
# The following packages will be UPDATED:
#
#   certifi                        2023.11.17-py311h06a4308_0 --> 2024.2.2-py311h06a4308_0
#   conda                             23.11.0-py311h06a4308_0 --> 24.1.0-py311h06a4308_0
#   openssl                                 3.0.12-h7f8727e_0 --> 3.0.13-h7f8727e_0
#
#
#
# ...

# %% [markdown]
# # Creating virtual environment with python 3.7

# %%
# !conda create --name myenv python=3.7 -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-22.3.1                 |   py37h06a4308_0         2.7 MB
#     python-3.7.16              |       h7a1cb2a_0        44.8 MB
#     setuptools-65.6.3          |   py37h06a4308_0         1.1 MB
#     wheel-0.38.4               |   py37h06a4308_0          63 KB
#     ------------------------------------------------------------
#                                            Total:        52.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
# ...

# %% [markdown]
# # Activate the environment

# %%
# !conda run -n myenv

# %% [markdown]
# # Install pytorch 1.7.1,torchvision==0.8.2,torchaudio==0.7.2 and cudatoolkit=11.0

# %%
# !conda install -n myenv pytorch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2 cudatoolkit=11.0 -c pytorch -y
# Out:
# Channels:
#  - pytorch
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - cudatoolkit=11.0
#     - pytorch==1.7.1
#     - torchaudio==0.7.2
#     - torchvision==0.8.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     cudatoolkit-11.0.221       |       h6bb024c_0       622.9 MB
#     flit-core-3.6.0            |     pyhd3eb1b0_0          42 KB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     giflib-5.2.1               |       h5eee18b_3          80 KB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     jpeg-9b                    |       h024ee3a_2         214 KB
#     lcms2-2.12                 |       h3be6417_0         312 KB
# ...

# %% [markdown]
# # Cloning to Nvidia's repo

# %%
# !conda run -n myenv git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...

# %%
# %cd \stylegan2-ada-pytorch
# Out:
# /content/stylegan2-ada-pytorch

# %%
# !conda run -n myenv dir
# Out:
# calc_metrics.py  Dockerfile	generate.py  metrics	   style_mixing.py  train.py
# dataset_tool.py  docker_run.sh	legacy.py    projector.py  torch_utils
# dnnlib		 docs		LICENSE.txt  README.md	   training

# %% [markdown]
# # Prepare the dataset

# %% [markdown]
# Before running the dataset_tool.py, install click and tqdm

# %%
# !conda run -n myenv python dataset_tool.py --source /content/drive/MyDrive/custom_dataset/input --dest /content/drive/MyDrive/custom_dataset/resized_dataset --width=256 --height=256 --resize-filter=box
# Out:
# dataset_tool.py:205: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
# dataset_tool.py:205: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
# 100%|██████████| 18/18 [00:00<00:00, 42.83it/s]

# %%
# !conda install -n myenv click
# Out:
# Channels:
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - click
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     click-8.0.4                |   py37h06a4308_0         152 KB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     zipp-3.11.0                |   py37h06a4308_0          19 KB
#     ------------------------------------------------------------
#                                            Total:         211 KB
#
# The following NEW packages will be INSTALLED:
#
#   click              pkgs/main/linux-64::click-8.0.4-py37h06a4308_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-4.11.3-py37h06a4308_0
#   zipp               pkgs/main/linux-64::zipp-3.11.0-py37h06a4308_0
#
#
# Proceed ([y]/n)? y
#
#
# ...

# %%
# !conda install -n myenv tqdm
# Out:
# Channels:
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.64.1                |   py37h06a4308_0         126 KB
#     ------------------------------------------------------------
#                                            Total:         126 KB
#
# The following NEW packages will be INSTALLED:
#
#   tqdm               pkgs/main/linux-64::tqdm-4.64.1-py37h06a4308_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
#
# done
# done
# done

# %% [markdown]
# # Train the model

# %% [markdown]
# Before running the train.py, install requests, psutil and scipy

# %%
# !conda run -n myenv python train.py --data /content/drive/MyDrive/custom_dataset/input_set --outdir /content/drive/MyDrive/custom_dataset/results
# Out:
# Traceback (most recent call last):
#   File "train.py", line 20, in <module>
#     from training import training_loop
#   File "/content/stylegan2-ada-pytorch/training/training_loop.py", line 25, in <module>
#     from metrics import metric_main
#   File "/content/stylegan2-ada-pytorch/metrics/metric_main.py", line 16, in <module>
#     from . import frechet_inception_distance
#   File "/content/stylegan2-ada-pytorch/metrics/frechet_inception_distance.py", line 15, in <module>
#     import scipy.linalg
# ModuleNotFoundError: No module named 'scipy'
#
# ERROR conda.cli.main_run:execute(124): `conda run python train.py --data /content/drive/MyDrive/custom_dataset/input_set --outdir /content/drive/MyDrive/custom_dataset/results` failed. (See above for error)

# %%
# !conda install -n myenv requests
# Out:
# Channels:
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotlipy-0.7.0             |py37h27cfd23_1003         320 KB
#     cffi-1.15.1                |   py37h5eee18b_3         240 KB
#     cryptography-39.0.1        |   py37h9ce1e76_0         1.4 MB
#     idna-3.4                   |   py37h06a4308_0          91 KB
#     pyopenssl-23.0.0           |   py37h06a4308_0          96 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     requests-2.28.1            |   py37h06a4308_0          92 KB
#     urllib3-1.26.14            |   py37h06a4308_0         195 KB
#     ------------------------------------------------------------
# ...

# %%
# !conda install -n myenv psutil
# Out:
# Channels:
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - psutil
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     psutil-5.9.0               |   py37h5eee18b_0         328 KB
#     ------------------------------------------------------------
#                                            Total:         328 KB
#
# The following NEW packages will be INSTALLED:
#
#   psutil             pkgs/main/linux-64::psutil-5.9.0-py37h5eee18b_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
#
# done
# done
# done

# %%
# !conda install -n myenv scipy
# Out:
# Channels:
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     fftw-3.3.9                 |       h27cfd23_1         2.3 MB
#     libgfortran-ng-11.2.0      |       h00389a5_1          20 KB
#     libgfortran5-11.2.0        |       h1234567_1         2.0 MB
#     scipy-1.7.3                |   py37h6c91a56_2        16.5 MB
#     ------------------------------------------------------------
#                                            Total:        20.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   fftw               pkgs/main/linux-64::fftw-3.3.9-h27cfd23_1
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-11.2.0-h00389a5_1
# ...

# %% [markdown]
# # Generate the images

# %%
# !conda run -n myenv python generate.py --outdir=/content/drive/MyDrive/custom_dataset/output --trunc=1 --seeds=85,265,297,849 --network=/content/drive/MyDrive/custom_dataset/result/network-snapshot-000000.pkl
# Out:
# Loading networks from "/content/drive/MyDrive/custom_dataset/result/network-snapshot-000000.pkl"...
# Generating image for seed 85 (0/4) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 265 (1/4) ...
# Generating image for seed 297 (2/4) ...
# Generating image for seed 849 (3/4) ...
